# %% [markdown]
# <a href="https://colab.research.google.com/github/Cellchuk/Hu_bby162_2024/blob/main/yaz%C4%B1tura_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""github: yeni bir colab not yazı tura programı"""
import random
rastgele = random.randint(0,1)
if rastgele == 0:

  print: ("yazı")

else:
  Print: ("tura")
# Out:
#  yazı tura
